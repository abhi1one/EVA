# %% [markdown]
# Assignment 6 vesrion 2
# * Step 1: Removing all Dense layers and updating model for receptive field with 1x1
# * Step 2: Removing / updating dropout places and fixing model arch; settingborder_mode='same' for all convolutions
# * Step 3:
#
# *Results*
# * Base Accuracy: 82.73
# * Version 2 Step 1 Val Accuracy: 82.74
# * Version 2 Step 2 Val acc:81.32 ; Train Acc:.9807 ; High overfitting

# %% [markdown]
# Importing al necessary keras, matplot, numpy libs

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Importing, loading data in train and test

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %% [markdown]
# Viewsing train data for labels.

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# Defigning function to plot model training validation accuracy and loss

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# Defining function to find and return accracy of trained model in percentage

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# Normalizing train and test data
# Converting labels from 1-D to 2-D with leangth of second dimention is num_class

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# Defigning Model and Compiling Model
#
# Applying step 2 changes.

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3))) #RF 3X3
model.add(Activation('relu'))

model.add(Convolution2D(48, 3, 3, border_mode='same')) #RF 5X5
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=(2, 2))) #RF 10X10
#Dropout post maxpooling is not help ful; should move this to conv with 14x14
#model.add(Dropout(0.25))

model.add(Convolution2D(96, 3, 3, border_mode='same')) #RF 12X12
model.add(Activation('relu'))

model.add(Convolution2D(96, 3, 3, border_mode='same')) #RF 14X14
model.add(Activation('relu'))

model.add(Dropout(0.25))

model.add(MaxPooling2D(pool_size=(2, 2))) #RF 28X28
#Dropout post maxpooling is not help ful; should move this to conv with 30x30
#model.add(Dropout(0.25))

model.add(Convolution2D(192, 3, 3, border_mode='same')) #RF 30X30
model.add(Activation('relu'))

model.add(Dropout(0.25))

model.add(Convolution2D(192, 3, 3, border_mode='same')) #RF 32X32
model.add(Activation('relu'))

#removing this as it doesn't seem logical to have maxpooling and dropout here
'''
model.add(MaxPooling2D(pool_size=(2, 2))) #RF 64X64
model.add(Dropout(0.25))
'''

'''
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))

model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
'''

model.add(Convolution2D(10, 1)) 
#model.add(BatchNormalization())

model.add(Convolution2D(10, 8)) 


model.add(Flatten())
model.add(Activation('softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_36 (Activation)   (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 32, 32, 48)        20784
# _________________________________________________________________
# activation_37 (Activation)   (None, 32, 32, 48)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 48)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 16, 16, 96)        41568
# _________________________________________________________________
# activation_38 (Activation)   (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 16, 16, 96)        83040
# _________________________________________________________________
# activation_39 (Activation)   (None, 16, 16, 96)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 96)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 96)          0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 8, 8, 192)         166080
# _________________________________________________________________
# activation_40 (Activation)   (None, 8, 8, 192)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 8, 8, 192)         331968
# _________________________________________________________________
# activation_41 (Activation)   (None, 8, 8, 192)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 8, 8, 10)          1930
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 1, 1, 10)          6410
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_42 (Activation)   (None, 10)                0
# =================================================================
# Total params: 653,124
# Trainable params: 653,124
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training for Epochs = 100 and comparing with Base accuracy is 82.73

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 12s 31ms/step - loss: 1.5511 - acc: 0.4333 - val_loss: 1.2487 - val_acc: 0.5619
# Epoch 2/100
# 390/390 [==============================] - 11s 28ms/step - loss: 1.0444 - acc: 0.6283 - val_loss: 0.9118 - val_acc: 0.6886
# Epoch 3/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.8247 - acc: 0.7113 - val_loss: 0.7948 - val_acc: 0.7299
# Epoch 4/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.7048 - acc: 0.7527 - val_loss: 0.7521 - val_acc: 0.7382
# Epoch 5/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.6190 - acc: 0.7836 - val_loss: 0.6739 - val_acc: 0.7691
# Epoch 6/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.5452 - acc: 0.8084 - val_loss: 0.6329 - val_acc: 0.7844
# Epoch 7/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.4747 - acc: 0.8326 - val_loss: 0.6064 - val_acc: 0.7939
# Epoch 8/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.4270 - acc: 0.8496 - val_loss: 0.5962 - val_acc: 0.7960
# Epoch 9/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.3716 - acc: 0.8701 - val_loss: 0.5996 - val_acc: 0.7978
# Epoch 10/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.3316 - acc: 0.8820 - val_loss: 0.5800 - val_acc: 0.8085
# Epoch 11/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.2912 - acc: 0.8959 - val_loss: 0.6059 - val_acc: 0.8034
# Epoch 12/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.2539 - acc: 0.9098 - val_loss: 0.6426 - val_acc: 0.8026
# Epoch 13/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.2379 - acc: 0.9159 - val_loss: 0.6819 - val_acc: 0.7920
# Epoch 14/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.2126 - acc: 0.9240 - val_loss: 0.6373 - val_acc: 0.8077
# Epoch 15/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1934 - acc: 0.9315 - val_loss: 0.6542 - val_acc: 0.8063
# Epoch 16/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1830 - acc: 0.9343 - val_loss: 0.6563 - val_acc: 0.8041
# Epoch 17/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1644 - acc: 0.9416 - val_loss: 0.7104 - val_acc: 0.8074
# Epoch 18/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1575 - acc: 0.9445 - val_loss: 0.7062 - val_acc: 0.7979
# Epoch 19/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1514 - acc: 0.9449 - val_loss: 0.7481 - val_acc: 0.7950
# Epoch 20/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1410 - acc: 0.9506 - val_loss: 0.7533 - val_acc: 0.8000
# Epoch 21/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1383 - acc: 0.9511 - val_loss: 0.7686 - val_acc: 0.8031
# Epoch 22/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1359 - acc: 0.9525 - val_loss: 0.7409 - val_acc: 0.8072
# Epoch 23/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1297 - acc: 0.9540 - val_loss: 0.8023 - val_acc: 0.8075
# Epoch 24/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1218 - acc: 0.9575 - val_loss: 0.7942 - val_acc: 0.8072
# Epoch 25/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1183 - acc: 0.9592 - val_loss: 0.7749 - val_acc: 0.8033
# Epoch 26/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1165 - acc: 0.9590 - val_loss: 0.7992 - val_acc: 0.8038
# Epoch 27/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.1153 - acc: 0.9594 - val_loss: 0.8318 - val_acc: 0.7977
# Epoch 28/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1158 - acc: 0.9594 - val_loss: 0.7974 - val_acc: 0.8003
# Epoch 29/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1110 - acc: 0.9616 - val_loss: 0.7993 - val_acc: 0.8080
# Epoch 30/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.1095 - acc: 0.9623 - val_loss: 0.7883 - val_acc: 0.8047
# Epoch 31/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.1114 - acc: 0.9604 - val_loss: 0.8225 - val_acc: 0.8036
# Epoch 32/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1017 - acc: 0.9646 - val_loss: 0.8103 - val_acc: 0.8083
# Epoch 33/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.1068 - acc: 0.9632 - val_loss: 0.8520 - val_acc: 0.8021
# Epoch 34/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.1052 - acc: 0.9636 - val_loss: 0.8141 - val_acc: 0.8090
# Epoch 35/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0984 - acc: 0.9663 - val_loss: 0.8154 - val_acc: 0.8022
# Epoch 36/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0983 - acc: 0.9666 - val_loss: 0.8219 - val_acc: 0.8091
# Epoch 37/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0943 - acc: 0.9668 - val_loss: 0.8394 - val_acc: 0.8048
# Epoch 38/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0911 - acc: 0.9688 - val_loss: 0.8506 - val_acc: 0.8092
# Epoch 39/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0956 - acc: 0.9664 - val_loss: 0.8465 - val_acc: 0.8130
# Epoch 40/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0924 - acc: 0.9687 - val_loss: 0.8195 - val_acc: 0.8084
# Epoch 41/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0853 - acc: 0.9711 - val_loss: 0.8424 - val_acc: 0.8113
# Epoch 42/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0934 - acc: 0.9679 - val_loss: 0.8761 - val_acc: 0.8041
# Epoch 43/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0885 - acc: 0.9704 - val_loss: 0.8880 - val_acc: 0.8039
# Epoch 44/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0891 - acc: 0.9693 - val_loss: 0.8881 - val_acc: 0.8087
# Epoch 45/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0916 - acc: 0.9688 - val_loss: 0.8859 - val_acc: 0.8053
# Epoch 46/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0958 - acc: 0.9676 - val_loss: 0.8563 - val_acc: 0.8043
# Epoch 47/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0920 - acc: 0.9693 - val_loss: 0.8594 - val_acc: 0.8080
# Epoch 48/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0885 - acc: 0.9690 - val_loss: 0.8874 - val_acc: 0.8081
# Epoch 49/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0860 - acc: 0.9708 - val_loss: 0.8862 - val_acc: 0.8062
# Epoch 50/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0804 - acc: 0.9724 - val_loss: 0.9169 - val_acc: 0.8078
# Epoch 51/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0858 - acc: 0.9707 - val_loss: 0.8718 - val_acc: 0.8127
# Epoch 52/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0814 - acc: 0.9730 - val_loss: 0.8634 - val_acc: 0.8131
# Epoch 53/100
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0839 - acc: 0.9713 - val_loss: 0.8931 - val_acc: 0.8134
# Epoch 54/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0798 - acc: 0.9731 - val_loss: 0.9280 - val_acc: 0.8049
# Epoch 55/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0845 - acc: 0.9716 - val_loss: 0.9151 - val_acc: 0.8059
# Epoch 56/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0809 - acc: 0.9734 - val_loss: 0.9734 - val_acc: 0.8055
# Epoch 57/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0801 - acc: 0.9734 - val_loss: 0.9694 - val_acc: 0.8003
# Epoch 58/100
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0818 - acc: 0.9724 - val_loss: 0.8818 - val_acc: 0.8088
# Epoch 59/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0722 - acc: 0.9756 - val_loss: 0.8879 - val_acc: 0.8092
# Epoch 60/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0740 - acc: 0.9759 - val_loss: 0.8812 - val_acc: 0.8079
# Epoch 61/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0791 - acc: 0.9733 - val_loss: 0.8901 - val_acc: 0.8124
# Epoch 62/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0803 - acc: 0.9729 - val_loss: 0.9403 - val_acc: 0.8051
# Epoch 63/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0773 - acc: 0.9740 - val_loss: 0.9124 - val_acc: 0.8050
# Epoch 64/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0793 - acc: 0.9736 - val_loss: 0.9541 - val_acc: 0.8107
# Epoch 65/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0707 - acc: 0.9764 - val_loss: 0.9999 - val_acc: 0.7998
# Epoch 66/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0723 - acc: 0.9762 - val_loss: 0.9695 - val_acc: 0.8103
# Epoch 67/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0740 - acc: 0.9748 - val_loss: 0.8912 - val_acc: 0.8077
# Epoch 68/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0762 - acc: 0.9751 - val_loss: 0.9186 - val_acc: 0.8059
# Epoch 69/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0727 - acc: 0.9754 - val_loss: 0.8874 - val_acc: 0.8151
# Epoch 70/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0708 - acc: 0.9757 - val_loss: 0.9281 - val_acc: 0.8070
# Epoch 71/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0774 - acc: 0.9747 - val_loss: 0.9669 - val_acc: 0.8110
# Epoch 72/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0712 - acc: 0.9765 - val_loss: 0.9365 - val_acc: 0.8066
# Epoch 73/100
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0773 - acc: 0.9736 - val_loss: 0.9131 - val_acc: 0.8077
# Epoch 74/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0684 - acc: 0.9774 - val_loss: 0.9586 - val_acc: 0.8131
# Epoch 75/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0662 - acc: 0.9786 - val_loss: 0.9695 - val_acc: 0.8079
# Epoch 76/100
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0646 - acc: 0.9785 - val_loss: 0.9518 - val_acc: 0.8133
# Epoch 77/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0694 - acc: 0.9770 - val_loss: 0.9659 - val_acc: 0.8112
# Epoch 78/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0785 - acc: 0.9739 - val_loss: 0.9278 - val_acc: 0.8103
# Epoch 79/100
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0680 - acc: 0.9781 - val_loss: 0.9406 - val_acc: 0.8039
# Epoch 80/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0677 - acc: 0.9772 - val_loss: 0.9365 - val_acc: 0.8142
# Epoch 81/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0675 - acc: 0.9770 - val_loss: 0.9530 - val_acc: 0.8109
# Epoch 82/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0736 - acc: 0.9761 - val_loss: 0.9510 - val_acc: 0.8092
# Epoch 83/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0665 - acc: 0.9785 - val_loss: 0.9555 - val_acc: 0.8154
# Epoch 84/100
# 390/390 [==============================] - 11s 27ms/step - loss: 0.0676 - acc: 0.9776 - val_loss: 1.0212 - val_acc: 0.8071
# Epoch 85/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0656 - acc: 0.9782 - val_loss: 0.9412 - val_acc: 0.8136
# Epoch 86/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0686 - acc: 0.9776 - val_loss: 0.9517 - val_acc: 0.8091
# Epoch 87/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0633 - acc: 0.9795 - val_loss: 0.9888 - val_acc: 0.8100
# Epoch 88/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0695 - acc: 0.9771 - val_loss: 0.9714 - val_acc: 0.8062
# Epoch 89/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0736 - acc: 0.9767 - val_loss: 0.9388 - val_acc: 0.8158
# Epoch 90/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0641 - acc: 0.9790 - val_loss: 1.0158 - val_acc: 0.8121
# Epoch 91/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0635 - acc: 0.9791 - val_loss: 1.0376 - val_acc: 0.8077
# Epoch 92/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0724 - acc: 0.9762 - val_loss: 0.9414 - val_acc: 0.8149
# Epoch 93/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0686 - acc: 0.9781 - val_loss: 0.9162 - val_acc: 0.8159
# Epoch 94/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0561 - acc: 0.9820 - val_loss: 0.9962 - val_acc: 0.8173
# Epoch 95/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0654 - acc: 0.9782 - val_loss: 1.0179 - val_acc: 0.8125
# Epoch 96/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0668 - acc: 0.9787 - val_loss: 0.9890 - val_acc: 0.8126
# Epoch 97/100
# 390/390 [==============================] - 10s 27ms/step - loss: 0.0634 - acc: 0.9797 - val_loss: 1.0251 - val_acc: 0.8137
# Epoch 98/100
# 390/390 [==============================] - 10s 26ms/step - loss: 0.0646 - acc: 0.9791 - val_loss: 0.9716 - val_acc: 0.8186
# Epoch 99/100
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0620 - acc: 0.9804 - val_loss: 1.0095 - val_acc: 0.8156
# Epoch 100/100
# 390/390 [==============================] - 11s 28ms/step - loss: 0.0620 - acc: 0.9802 - val_loss: 1.0222 - val_acc: 0.8132
# Model took 1046.67 seconds to train
# Accuracy on test data is: 81.32
