# %% [markdown]
# Session 7 Task 2
#
# Problem statement:
# Design this network (CIFAR10):
# 1. Image result for eNAS network architecture
# 2. The lines you see are the skip-connections. You need to add them
# 3. Train for 100 Epochs (add BN and ReLU after every layer)
# 4. Submit the results

# %% [markdown]
# Importing al necessary keras, matplot, numpy libs

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, SeparableConv2D, DepthwiseConv2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
#preparing check point for saving weights via callback
from google.colab import drive
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Importing, loading data in train and test

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# Viewsing train data for labels.

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# Defigning function to plot model training validation accuracy and loss

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# Defining function to find and return accracy of trained model in percentage

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# Normalizing train and test data
# Converting labels from 1-D to 2-D with leangth of second dimention is num_class

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# Defining ENAS network arch

# %%
#Defining model

#importing necessary modules
from keras.models import Model
from keras.layers import Input, Flatten, Conv2D
from keras.layers.merge import concatenate

# input layer
visible = Input(shape=(32,32,3))

# layer1 Sep 5x5 
layer1 = SeparableConv2D(32, (5, 5), padding="same", activation='relu') (visible)
layer1 = (BatchNormalization())(layer1) 

# layer2 conv 5x5
layer2 = Conv2D(32, (5, 5), padding="same", activation='relu') (layer1)
layer2 = (BatchNormalization())(layer2) 

# layer3 conv 5x5
layer3 = Conv2D(32, (5, 5), padding="same", activation='relu') (layer2)
layer3 = (BatchNormalization())(layer3) 

# layer4 Sep 5x5 from 1
layer4 = SeparableConv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer3]))
layer4 = (BatchNormalization())(layer4) 

# pool1 maxpooling skip from 1
btl_nek1 = Conv2D(48, (1, 1), padding="same", activation='relu') (concatenate([layer1, layer4]))
pool1 = MaxPooling2D(pool_size=(2, 2), padding="same", strides=1) (btl_nek1)

# layer5 sep 3x3 
layer5 = SeparableConv2D(32, (3, 3), padding="same", activation='relu') (pool1)
layer5 = (BatchNormalization())(layer5) 

# layer6 conv 5x5 skip from 1,4
layer6 = Conv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer4, layer5]))
layer6 = (BatchNormalization())(layer6) 

# layer7 sep 3x3 skip from 3,4,5
layer7 = SeparableConv2D(32, (3, 1), padding="same", activation='relu') (concatenate([layer3, layer4, layer5, layer6]))
layer7 = (BatchNormalization())(layer7) 

# layer8 sep 5x5 skip from 1,3,4,5,6
layer8 = SeparableConv2D(32, (3, 3), padding="same", activation='relu') (concatenate([layer1, layer3, layer4, layer5, layer6, layer7]))
layer8 = (BatchNormalization())(layer8) 

# pool2 maxpooling skip from 1,4,5,7
btl_nek10 = Conv2D(128, (1, 1), padding="same", activation='relu') (concatenate([layer1, layer4, layer5, layer7, layer8]))
pool2 = MaxPooling2D(pool_size=(2, 2), padding="same", strides=1) (btl_nek10)

# layer9 conv 5x5 skip from 6
layer9 = Conv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer6, pool2]))
layer9 = (BatchNormalization())(layer9) 

# layer10 sep 5x5 skip from 1,2,4,7
layer10 = SeparableConv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer2, layer4, layer7, layer9]))
layer10 = (BatchNormalization())(layer10) 

# layer11 conv 3x3 skip from 2,3,5,9
layer11 = Conv2D(32, (3, 3), padding="same", activation='relu') (concatenate([layer2, layer3, layer5, layer9, layer10]))
layer11 = (BatchNormalization())(layer11) 
  
# layer12 sep 5x5 skip from 3,4,5,7,10
layer12 = SeparableConv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer3, layer4, layer5, layer7, layer10, layer11]))
layer12 = (BatchNormalization())(layer12) 

# last part skip from 4,8,12
flat = Flatten()(concatenate([layer4, layer7, layer10, layer12]))
last = Dense(10)(flat)
output = Dense(10, activation='softmax')(last)
model = Model(inputs=visible, outputs=output)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0616 15:47:43.430039 140359690565504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0616 15:47:43.472299 140359690565504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0616 15:47:43.481420 140359690565504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0616 15:47:43.541370 140359690565504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0616 15:47:43.542277 140359690565504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0616 15:47:46.417355 140359690565504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0616 15:47:46.832184 140359690565504 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 32)   203         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   25632       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   25632       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 64)   0           batch_normalization_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 32, 32, 32)   3680        concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 64)   0           batch_normalization_1[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 48)   3120        concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 48)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 32, 32, 32)   2000        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 96)   0           batch_normalization_1[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   76832       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 128)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 32, 32, 32)   4512        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 32)   128         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 192)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 32, 32, 32)   7904        concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 32)   128         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 160)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  20608       concatenate_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 160)  0           batch_normalization_6[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 32)   128032      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 160)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 32, 32, 32)   9152        concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 160)  0           batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   46112       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 192)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 32, 32, 32)   10976       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 32, 32, 128)  0           batch_normalization_4[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 131072)       0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1310730     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           110         dense_1[0][0]
# ==================================================================================================
# Total params: 1,676,771
# Trainable params: 1,676,003
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %%
#Adding lr rate scheduling and model saving
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau

def lr_scheduler(epoch):
  lr = 1e-3
  if epoch > 80:
    lr *= 0.5e-3
  elif epoch > 60:
    lr *= 1e-3
  elif epoch > 40:
    lr *= 1e-2
  elif epoch > 20:
    lr *= 1e-1
  print('Learning rate: ', lr)
  return lr
  #return round(0.001 * 1/(1 + 0.319 * epoch), 10)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

filepath="/content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-{epoch:02d}-{val_acc:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

callback_list = [checkpoint, lr_reducer, LearningRateScheduler(lr_scheduler)]#[LearningRateScheduler(scheduler, verbose=1), checkpoint]

# Compile the model
model.compile(optimizer=Adam(lr=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Training for Epochs = 100

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        rotation_range=15, width_shift_range=0.1, height_shift_range=0.1)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1, 
                                 callbacks=callback_list)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   from ipykernel import kernelapp as app
# Epoch 1/100
# Learning rate:  0.001
# 390/390 [==============================] - 77s 197ms/step - loss: 10.9422 - acc: 0.2924 - val_loss: 12.3493 - val_acc: 0.2276
#
# Epoch 00001: val_acc improved from -inf to 0.22760, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-01-0.2276.hdf5
# Epoch 2/100
# Learning rate:  0.001
# 390/390 [==============================] - 68s 175ms/step - loss: 10.5881 - acc: 0.3310 - val_loss: 10.6001 - val_acc: 0.3323
#
# Epoch 00002: val_acc improved from 0.22760 to 0.33230, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-02-0.3323.hdf5
# Epoch 3/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 173ms/step - loss: 10.2976 - acc: 0.3512 - val_loss: 11.3241 - val_acc: 0.2915
#
# Epoch 00003: val_acc did not improve from 0.33230
# Epoch 4/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 173ms/step - loss: 10.2542 - acc: 0.3564 - val_loss: 10.1264 - val_acc: 0.3667
#
# Epoch 00004: val_acc improved from 0.33230 to 0.36670, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-04-0.3667.hdf5
# Epoch 5/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 173ms/step - loss: 9.8414 - acc: 0.3825 - val_loss: 10.0635 - val_acc: 0.3715
#
# Epoch 00005: val_acc improved from 0.36670 to 0.37150, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-05-0.3715.hdf5
# Epoch 6/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 173ms/step - loss: 9.6133 - acc: 0.3976 - val_loss: 9.9099 - val_acc: 0.3804
#
# Epoch 00006: val_acc improved from 0.37150 to 0.38040, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-06-0.3804.hdf5
# Epoch 7/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 172ms/step - loss: 9.5597 - acc: 0.4010 - val_loss: 9.6680 - val_acc: 0.3948
#
# Epoch 00007: val_acc improved from 0.38040 to 0.39480, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-07-0.3948.hdf5
# Epoch 8/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 172ms/step - loss: 9.7217 - acc: 0.3909 - val_loss: 10.3704 - val_acc: 0.3525
#
# Epoch 00008: val_acc did not improve from 0.39480
# Epoch 9/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 173ms/step - loss: 9.3848 - acc: 0.4123 - val_loss: 9.1775 - val_acc: 0.4266
#
# Epoch 00009: val_acc improved from 0.39480 to 0.42660, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-09-0.4266.hdf5
# Epoch 10/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 172ms/step - loss: 9.3386 - acc: 0.4156 - val_loss: 9.1654 - val_acc: 0.4278
#
# Epoch 00010: val_acc improved from 0.42660 to 0.42780, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-10-0.4278.hdf5
# Epoch 11/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 172ms/step - loss: 9.4115 - acc: 0.4118 - val_loss: 9.9618 - val_acc: 0.3791
#
# Epoch 00011: val_acc did not improve from 0.42780
# Epoch 12/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 172ms/step - loss: 9.3578 - acc: 0.4153 - val_loss: 10.8379 - val_acc: 0.3237
#
# Epoch 00012: val_acc did not improve from 0.42780
# Epoch 13/100
# Learning rate:  0.001
# 390/390 [==============================] - 68s 173ms/step - loss: 9.2417 - acc: 0.4220 - val_loss: 8.9919 - val_acc: 0.4385
#
# Epoch 00013: val_acc improved from 0.42780 to 0.43850, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-13-0.4385.hdf5
# Epoch 14/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 172ms/step - loss: 9.2752 - acc: 0.4207 - val_loss: 8.5111 - val_acc: 0.4682
#
# Epoch 00014: val_acc improved from 0.43850 to 0.46820, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-14-0.4682.hdf5
# Epoch 15/100
# Learning rate:  0.001
# 390/390 [==============================] - 97s 249ms/step - loss: 9.0902 - acc: 0.4318 - val_loss: 11.5077 - val_acc: 0.2838
#
# Epoch 00015: val_acc did not improve from 0.46820
# Epoch 16/100
# Learning rate:  0.001
# 390/390 [==============================] - 96s 245ms/step - loss: 9.2404 - acc: 0.4232 - val_loss: 8.8175 - val_acc: 0.4496
#
# Epoch 00016: val_acc did not improve from 0.46820
# Epoch 17/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 173ms/step - loss: 8.8830 - acc: 0.4452 - val_loss: 8.5055 - val_acc: 0.4687
#
# Epoch 00017: val_acc improved from 0.46820 to 0.46870, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-17-0.4687.hdf5
# Epoch 18/100
# Learning rate:  0.001
# 390/390 [==============================] - 143s 367ms/step - loss: 8.9613 - acc: 0.4400 - val_loss: 9.0356 - val_acc: 0.4352
#
# Epoch 00018: val_acc did not improve from 0.46870
# Epoch 19/100
# Learning rate:  0.001
# 390/390 [==============================] - 126s 324ms/step - loss: 8.9758 - acc: 0.4395 - val_loss: 8.6654 - val_acc: 0.4593
#
# Epoch 00019: val_acc did not improve from 0.46870
# Epoch 20/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 171ms/step - loss: 9.0010 - acc: 0.4378 - val_loss: 9.5107 - val_acc: 0.4064
#
# Epoch 00020: val_acc did not improve from 0.46870
# Epoch 21/100
# Learning rate:  0.001
# 390/390 [==============================] - 67s 172ms/step - loss: 8.6016 - acc: 0.4624 - val_loss: 10.1210 - val_acc: 0.3691
#
# Epoch 00021: val_acc did not improve from 0.46870
# Epoch 22/100
# Learning rate:  0.0001
# 390/390 [==============================] - 120s 308ms/step - loss: 8.4568 - acc: 0.4713 - val_loss: 7.7249 - val_acc: 0.5172
#
# Epoch 00022: val_acc improved from 0.46870 to 0.51720, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-22-0.5172.hdf5
# Epoch 23/100
# Learning rate:  0.0001
# 390/390 [==============================] - 114s 291ms/step - loss: 8.1855 - acc: 0.4881 - val_loss: 7.7097 - val_acc: 0.5180
#
# Epoch 00023: val_acc improved from 0.51720 to 0.51800, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-23-0.5180.hdf5
# Epoch 24/100
# Learning rate:  0.0001
# 390/390 [==============================] - 133s 342ms/step - loss: 8.0866 - acc: 0.4945 - val_loss: 7.6195 - val_acc: 0.5238
#
# Epoch 00024: val_acc improved from 0.51800 to 0.52380, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-24-0.5238.hdf5
# Epoch 25/100
# Learning rate:  0.0001
# 390/390 [==============================] - 139s 358ms/step - loss: 8.0605 - acc: 0.4958 - val_loss: 7.5972 - val_acc: 0.5252
#
# Epoch 00025: val_acc improved from 0.52380 to 0.52520, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-25-0.5252.hdf5
# Epoch 26/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.9222 - acc: 0.5044 - val_loss: 7.5792 - val_acc: 0.5256
#
# Epoch 00026: val_acc improved from 0.52520 to 0.52560, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-26-0.5256.hdf5
# Epoch 27/100
# Learning rate:  0.0001
# 390/390 [==============================] - 89s 229ms/step - loss: 7.9754 - acc: 0.5009 - val_loss: 7.5883 - val_acc: 0.5259
#
# Epoch 00027: val_acc improved from 0.52560 to 0.52590, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-27-0.5259.hdf5
# Epoch 28/100
# Learning rate:  0.0001
# 390/390 [==============================] - 130s 333ms/step - loss: 7.8687 - acc: 0.5079 - val_loss: 7.6002 - val_acc: 0.5246
#
# Epoch 00028: val_acc did not improve from 0.52590
# Epoch 29/100
# Learning rate:  0.0001
# 390/390 [==============================] - 138s 354ms/step - loss: 7.8557 - acc: 0.5084 - val_loss: 7.4998 - val_acc: 0.5313
#
# Epoch 00029: val_acc improved from 0.52590 to 0.53130, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-29-0.5313.hdf5
# Epoch 30/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.8349 - acc: 0.5099 - val_loss: 7.4646 - val_acc: 0.5332
#
# Epoch 00030: val_acc improved from 0.53130 to 0.53320, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-30-0.5332.hdf5
# Epoch 31/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 365ms/step - loss: 7.8192 - acc: 0.5109 - val_loss: 7.4227 - val_acc: 0.5352
#
# Epoch 00031: val_acc improved from 0.53320 to 0.53520, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-31-0.5352.hdf5
# Epoch 32/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.8216 - acc: 0.5101 - val_loss: 7.4811 - val_acc: 0.5322
#
# Epoch 00032: val_acc did not improve from 0.53520
# Epoch 33/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.7814 - acc: 0.5128 - val_loss: 7.4725 - val_acc: 0.5329
#
# Epoch 00033: val_acc did not improve from 0.53520
# Epoch 34/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.7089 - acc: 0.5174 - val_loss: 7.5004 - val_acc: 0.5310
#
# Epoch 00034: val_acc did not improve from 0.53520
# Epoch 35/100
# Learning rate:  0.0001
# 390/390 [==============================] - 143s 366ms/step - loss: 7.6946 - acc: 0.5186 - val_loss: 7.3977 - val_acc: 0.5376
#
# Epoch 00035: val_acc improved from 0.53520 to 0.53760, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-35-0.5376.hdf5
# Epoch 36/100
# Learning rate:  0.0001
# 390/390 [==============================] - 143s 366ms/step - loss: 7.7365 - acc: 0.5160 - val_loss: 7.3602 - val_acc: 0.5399
#
# Epoch 00036: val_acc improved from 0.53760 to 0.53990, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-36-0.5399.hdf5
# Epoch 37/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.6740 - acc: 0.5195 - val_loss: 7.3410 - val_acc: 0.5414
#
# Epoch 00037: val_acc improved from 0.53990 to 0.54140, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-37-0.5414.hdf5
# Epoch 38/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.6282 - acc: 0.5227 - val_loss: 7.3797 - val_acc: 0.5384
#
# Epoch 00038: val_acc did not improve from 0.54140
# Epoch 39/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 365ms/step - loss: 7.6544 - acc: 0.5208 - val_loss: 7.3620 - val_acc: 0.5390
#
# Epoch 00039: val_acc did not improve from 0.54140
# Epoch 40/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.6775 - acc: 0.5193 - val_loss: 7.3229 - val_acc: 0.5421
#
# Epoch 00040: val_acc improved from 0.54140 to 0.54210, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-40-0.5421.hdf5
# Epoch 41/100
# Learning rate:  0.0001
# 390/390 [==============================] - 142s 364ms/step - loss: 7.6115 - acc: 0.5235 - val_loss: 7.3014 - val_acc: 0.5433
#
# Epoch 00041: val_acc improved from 0.54210 to 0.54330, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-41-0.5433.hdf5
# Epoch 42/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5930 - acc: 0.5246 - val_loss: 7.2875 - val_acc: 0.5437
#
# Epoch 00042: val_acc improved from 0.54330 to 0.54370, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-42-0.5437.hdf5
# Epoch 43/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 364ms/step - loss: 7.6039 - acc: 0.5243 - val_loss: 7.2812 - val_acc: 0.5444
#
# Epoch 00043: val_acc improved from 0.54370 to 0.54440, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-43-0.5444.hdf5
# Epoch 44/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 363ms/step - loss: 7.6143 - acc: 0.5231 - val_loss: 7.2907 - val_acc: 0.5431
#
# Epoch 00044: val_acc did not improve from 0.54440
# Epoch 45/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5568 - acc: 0.5269 - val_loss: 7.2925 - val_acc: 0.5435
#
# Epoch 00045: val_acc did not improve from 0.54440
# Epoch 46/100
# Learning rate:  1e-05
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5712 - acc: 0.5262 - val_loss: 7.2963 - val_acc: 0.5436
#
# Epoch 00046: val_acc did not improve from 0.54440
# Epoch 47/100
# Learning rate:  1e-05
# 390/390 [==============================] - 143s 366ms/step - loss: 7.6066 - acc: 0.5238 - val_loss: 7.2872 - val_acc: 0.5445
#
# Epoch 00047: val_acc improved from 0.54440 to 0.54450, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-47-0.5445.hdf5
# Epoch 48/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 364ms/step - loss: 7.5866 - acc: 0.5250 - val_loss: 7.2820 - val_acc: 0.5447
#
# Epoch 00048: val_acc improved from 0.54450 to 0.54470, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-48-0.5447.hdf5
# Epoch 49/100
# Learning rate:  1e-05
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5870 - acc: 0.5251 - val_loss: 7.2756 - val_acc: 0.5443
#
# Epoch 00049: val_acc did not improve from 0.54470
# Epoch 50/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5501 - acc: 0.5273 - val_loss: 7.2679 - val_acc: 0.5439
#
# Epoch 00050: val_acc did not improve from 0.54470
# Epoch 51/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 364ms/step - loss: 7.5557 - acc: 0.5271 - val_loss: 7.2641 - val_acc: 0.5444
#
# Epoch 00051: val_acc did not improve from 0.54470
# Epoch 52/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 364ms/step - loss: 7.5330 - acc: 0.5280 - val_loss: 7.2742 - val_acc: 0.5444
#
# Epoch 00052: val_acc did not improve from 0.54470
# Epoch 53/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5281 - acc: 0.5288 - val_loss: 7.2898 - val_acc: 0.5440
#
# Epoch 00053: val_acc did not improve from 0.54470
# Epoch 54/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4895 - acc: 0.5307 - val_loss: 7.2930 - val_acc: 0.5432
#
# Epoch 00054: val_acc did not improve from 0.54470
# Epoch 55/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 364ms/step - loss: 7.5245 - acc: 0.5290 - val_loss: 7.2951 - val_acc: 0.5437
#
# Epoch 00055: val_acc did not improve from 0.54470
# Epoch 56/100
# Learning rate:  1e-05
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5409 - acc: 0.5278 - val_loss: 7.2891 - val_acc: 0.5440
#
# Epoch 00056: val_acc did not improve from 0.54470
# Epoch 57/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4926 - acc: 0.5308 - val_loss: 7.2933 - val_acc: 0.5435
#
# Epoch 00057: val_acc did not improve from 0.54470
# Epoch 58/100
# Learning rate:  1e-05
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5112 - acc: 0.5297 - val_loss: 7.3036 - val_acc: 0.5425
#
# Epoch 00058: val_acc did not improve from 0.54470
# Epoch 59/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5009 - acc: 0.5308 - val_loss: 7.3022 - val_acc: 0.5425
#
# Epoch 00059: val_acc did not improve from 0.54470
# Epoch 60/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 364ms/step - loss: 7.4612 - acc: 0.5331 - val_loss: 7.3038 - val_acc: 0.5431
#
# Epoch 00060: val_acc did not improve from 0.54470
# Epoch 61/100
# Learning rate:  1e-05
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4893 - acc: 0.5310 - val_loss: 7.2849 - val_acc: 0.5446
#
# Epoch 00061: val_acc did not improve from 0.54470
# Epoch 62/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5076 - acc: 0.5301 - val_loss: 7.2866 - val_acc: 0.5445
#
# Epoch 00062: val_acc did not improve from 0.54470
# Epoch 63/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4807 - acc: 0.5317 - val_loss: 7.2873 - val_acc: 0.5445
#
# Epoch 00063: val_acc did not improve from 0.54470
# Epoch 64/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4798 - acc: 0.5318 - val_loss: 7.2884 - val_acc: 0.5444
#
# Epoch 00064: val_acc did not improve from 0.54470
# Epoch 65/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4968 - acc: 0.5304 - val_loss: 7.2886 - val_acc: 0.5442
#
# Epoch 00065: val_acc did not improve from 0.54470
# Epoch 66/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5090 - acc: 0.5296 - val_loss: 7.2828 - val_acc: 0.5439
#
# Epoch 00066: val_acc did not improve from 0.54470
# Epoch 67/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4839 - acc: 0.5314 - val_loss: 7.2841 - val_acc: 0.5451
#
# Epoch 00067: val_acc improved from 0.54470 to 0.54510, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-67-0.5451.hdf5
# Epoch 68/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4804 - acc: 0.5319 - val_loss: 7.2797 - val_acc: 0.5444
#
# Epoch 00068: val_acc did not improve from 0.54510
# Epoch 69/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5189 - acc: 0.5291 - val_loss: 7.2867 - val_acc: 0.5441
#
# Epoch 00069: val_acc did not improve from 0.54510
# Epoch 70/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 364ms/step - loss: 7.5084 - acc: 0.5300 - val_loss: 7.2850 - val_acc: 0.5449
#
# Epoch 00070: val_acc did not improve from 0.54510
# Epoch 71/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5274 - acc: 0.5286 - val_loss: 7.2814 - val_acc: 0.5446
#
# Epoch 00071: val_acc did not improve from 0.54510
# Epoch 72/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4891 - acc: 0.5311 - val_loss: 7.2880 - val_acc: 0.5440
#
# Epoch 00072: val_acc did not improve from 0.54510
# Epoch 73/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4866 - acc: 0.5311 - val_loss: 7.2886 - val_acc: 0.5442
#
# Epoch 00073: val_acc did not improve from 0.54510
# Epoch 74/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 364ms/step - loss: 7.5333 - acc: 0.5281 - val_loss: 7.2904 - val_acc: 0.5438
#
# Epoch 00074: val_acc did not improve from 0.54510
# Epoch 75/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5154 - acc: 0.5293 - val_loss: 7.2849 - val_acc: 0.5448
#
# Epoch 00075: val_acc did not improve from 0.54510
# Epoch 76/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5226 - acc: 0.5290 - val_loss: 7.2807 - val_acc: 0.5445
#
# Epoch 00076: val_acc did not improve from 0.54510
# Epoch 77/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5070 - acc: 0.5298 - val_loss: 7.2770 - val_acc: 0.5445
#
# Epoch 00077: val_acc did not improve from 0.54510
# Epoch 78/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5003 - acc: 0.5300 - val_loss: 7.2895 - val_acc: 0.5444
#
# Epoch 00078: val_acc did not improve from 0.54510
# Epoch 79/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4652 - acc: 0.5324 - val_loss: 7.2829 - val_acc: 0.5448
#
# Epoch 00079: val_acc did not improve from 0.54510
# Epoch 80/100
# Learning rate:  1e-06
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4841 - acc: 0.5314 - val_loss: 7.2863 - val_acc: 0.5447
#
# Epoch 00080: val_acc did not improve from 0.54510
# Epoch 81/100
# Learning rate:  1e-06
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4858 - acc: 0.5316 - val_loss: 7.2826 - val_acc: 0.5450
#
# Epoch 00081: val_acc did not improve from 0.54510
# Epoch 82/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4580 - acc: 0.5326 - val_loss: 7.2825 - val_acc: 0.5441
#
# Epoch 00082: val_acc did not improve from 0.54510
# Epoch 83/100
# Learning rate:  5e-07
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5499 - acc: 0.5270 - val_loss: 7.2721 - val_acc: 0.5447
#
# Epoch 00083: val_acc did not improve from 0.54510
# Epoch 84/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4846 - acc: 0.5311 - val_loss: 7.2791 - val_acc: 0.5447
#
# Epoch 00084: val_acc did not improve from 0.54510
# Epoch 85/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5431 - acc: 0.5277 - val_loss: 7.2771 - val_acc: 0.5444
#
# Epoch 00085: val_acc did not improve from 0.54510
# Epoch 86/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 364ms/step - loss: 7.5071 - acc: 0.5300 - val_loss: 7.2794 - val_acc: 0.5442
#
# Epoch 00086: val_acc did not improve from 0.54510
# Epoch 87/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4876 - acc: 0.5313 - val_loss: 7.2727 - val_acc: 0.5446
#
# Epoch 00087: val_acc did not improve from 0.54510
# Epoch 88/100
# Learning rate:  5e-07
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5086 - acc: 0.5300 - val_loss: 7.2796 - val_acc: 0.5448
#
# Epoch 00088: val_acc did not improve from 0.54510
# Epoch 89/100
# Learning rate:  5e-07
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5477 - acc: 0.5279 - val_loss: 7.2784 - val_acc: 0.5447
#
# Epoch 00089: val_acc did not improve from 0.54510
# Epoch 90/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5319 - acc: 0.5286 - val_loss: 7.2801 - val_acc: 0.5441
#
# Epoch 00090: val_acc did not improve from 0.54510
# Epoch 91/100
# Learning rate:  5e-07
# 390/390 [==============================] - 143s 365ms/step - loss: 7.5181 - acc: 0.5297 - val_loss: 7.2762 - val_acc: 0.5445
#
# Epoch 00091: val_acc did not improve from 0.54510
# Epoch 92/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5057 - acc: 0.5296 - val_loss: 7.2808 - val_acc: 0.5449
#
# Epoch 00092: val_acc did not improve from 0.54510
# Epoch 93/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5087 - acc: 0.5299 - val_loss: 7.2739 - val_acc: 0.5448
#
# Epoch 00093: val_acc did not improve from 0.54510
# Epoch 94/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.5089 - acc: 0.5298 - val_loss: 7.2685 - val_acc: 0.5452
#
# Epoch 00094: val_acc improved from 0.54510 to 0.54520, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-94-0.5452.hdf5
# Epoch 95/100
# Learning rate:  5e-07
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4870 - acc: 0.5311 - val_loss: 7.2677 - val_acc: 0.5453
#
# Epoch 00095: val_acc improved from 0.54520 to 0.54530, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-95-0.5453.hdf5
# Epoch 96/100
# Learning rate:  5e-07
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5299 - acc: 0.5280 - val_loss: 7.2823 - val_acc: 0.5441
#
# Epoch 00096: val_acc did not improve from 0.54530
# Epoch 97/100
# Learning rate:  5e-07
# 390/390 [==============================] - 143s 366ms/step - loss: 7.4948 - acc: 0.5307 - val_loss: 7.2781 - val_acc: 0.5445
#
# Epoch 00097: val_acc did not improve from 0.54530
# Epoch 98/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4937 - acc: 0.5307 - val_loss: 7.2776 - val_acc: 0.5445
#
# Epoch 00098: val_acc did not improve from 0.54530
# Epoch 99/100
# Learning rate:  5e-07
# 390/390 [==============================] - 143s 366ms/step - loss: 7.5113 - acc: 0.5301 - val_loss: 7.2669 - val_acc: 0.5453
#
# Epoch 00099: val_acc did not improve from 0.54530
# Epoch 100/100
# Learning rate:  5e-07
# 390/390 [==============================] - 142s 365ms/step - loss: 7.4472 - acc: 0.5333 - val_loss: 7.2695 - val_acc: 0.5454
#
# Epoch 00100: val_acc improved from 0.54530 to 0.54540, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v3_final_weights-improvement-100-0.5454.hdf5
# Model took 12749.23 seconds to train
# Accuracy on test data is: 54.54
