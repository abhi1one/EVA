# %% [markdown]
# Session 7 Task 2
#
# Problem statement:
# Design this network (CIFAR10):
# 1. Image result for eNAS network architecture
# 2. The lines you see are the skip-connections. You need to add them
# 3. Train for 100 Epochs (add BN and ReLU after every layer)
# 4. Submit the results

# %% [markdown]
# Importing al necessary keras, matplot, numpy libs

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, SeparableConv2D, DepthwiseConv2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
#preparing check point for saving weights via callback
from google.colab import drive
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Importing, loading data in train and test

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# Viewsing train data for labels.

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# Defigning function to plot model training validation accuracy and loss

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# Defining function to find and return accracy of trained model in percentage

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# Normalizing train and test data
# Converting labels from 1-D to 2-D with leangth of second dimention is num_class

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# Defining ENAS network arch
# Increasing Channels for all layers to 64

# %%
#Defining model

#importing necessary modules
from keras.models import Model
from keras.layers import Input, Flatten, Conv2D
from keras.layers.merge import concatenate

# input layer
visible = Input(shape=(32,32,3))

# layer1 Sep 5x5 
layer1 = SeparableConv2D(64, (5, 5), padding="same", activation='relu') (visible)
layer1 = (BatchNormalization())(layer1) 

# layer2 conv 5x5
layer2 = Conv2D(64, (5, 5), padding="same", activation='relu') (layer1)
layer2 = (BatchNormalization())(layer2) 

# layer3 conv 5x5
layer3 = Conv2D(64, (5, 5), padding="same", activation='relu') (layer2)
layer3 = (BatchNormalization())(layer3) 

# layer4 Sep 5x5 from 1
layer4 = SeparableConv2D(64, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer3]))
layer4 = (BatchNormalization())(layer4) 

# pool1 maxpooling skip from 1
btl_nek1 = Conv2D(96, (1, 1), padding="same", activation='relu') (concatenate([layer1, layer4]))
pool1 = MaxPooling2D(pool_size=(2, 2), padding="same", strides=1) (btl_nek1)

# layer5 sep 3x3 
layer5 = SeparableConv2D(64, (3, 3), padding="same", activation='relu') (pool1)
layer5 = (BatchNormalization())(layer5) 

# layer6 conv 5x5 skip from 1,4
layer6 = Conv2D(64, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer4, layer5]))
layer6 = (BatchNormalization())(layer6) 

# layer7 sep 3x3 skip from 3,4,5
layer7 = SeparableConv2D(64, (3, 1), padding="same", activation='relu') (concatenate([layer3, layer4, layer5, layer6]))
layer7 = (BatchNormalization())(layer7) 

# layer8 sep 5x5 skip from 1,3,4,5,6
layer8 = SeparableConv2D(64, (3, 3), padding="same", activation='relu') (concatenate([layer1, layer3, layer4, layer5, layer6, layer7]))
layer8 = (BatchNormalization())(layer8) 

# pool2 maxpooling skip from 1,4,5,7
btl_nek10 = Conv2D(256, (1, 1), padding="same", activation='relu') (concatenate([layer1, layer4, layer5, layer7, layer8]))
pool2 = MaxPooling2D(pool_size=(2, 2), padding="same", strides=1) (btl_nek10)

# layer9 conv 5x5 skip from 6
layer9 = Conv2D(64, (5, 5), padding="same", activation='relu') (concatenate([layer6, pool2]))
layer9 = (BatchNormalization())(layer9) 

# layer10 sep 5x5 skip from 1,2,4,7
layer10 = SeparableConv2D(64, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer2, layer4, layer7, layer9]))
layer10 = (BatchNormalization())(layer10) 

# layer11 conv 3x3 skip from 2,3,5,9
layer11 = Conv2D(64, (3, 3), padding="same", activation='relu') (concatenate([layer2, layer3, layer5, layer9, layer10]))
layer11 = (BatchNormalization())(layer11) 
  
# layer12 sep 5x5 skip from 3,4,5,7,10
layer12 = SeparableConv2D(64, (5, 5), padding="same", activation='relu') (concatenate([layer3, layer4, layer5, layer7, layer10, layer11]))
layer12 = (BatchNormalization())(layer12) 

# last part skip from 4,8,12
btl_nck3 = Convolution2D(10, 1, padding="same", activation='relu')(concatenate([layer4, layer7, layer10, layer12]))
btl_nck3 = (BatchNormalization())(btl_nck3) 

last = Convolution2D(10, 32)(btl_nck3)
output = Flatten() (last)
output = (Activation('softmax')) (output)


model = Model(inputs=visible, outputs=output)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0618 07:40:06.602711 140692701116288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0618 07:40:06.639679 140692701116288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0618 07:40:06.647150 140692701116288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0618 07:40:06.694320 140692701116288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0618 07:40:06.695264 140692701116288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0618 07:40:09.642859 140692701116288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0618 07:40:10.173134 140692701116288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 64)   331         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   102464      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   102464      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 128)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 32, 32, 64)   11456       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 96)   12384       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 96)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 32, 32, 64)   7072        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 192)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   307264      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 256)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 32, 32, 64)   17216       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 384)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 32, 32, 64)   28096       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 320)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 256)  82176       concatenate_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 320)  0           batch_normalization_6[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   512064      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 320)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 32, 32, 64)   28544       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 320)  0           batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   184384      concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 384)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 32, 32, 64)   34240       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 32, 32, 256)  0           batch_normalization_4[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 10)   2570        concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 10)   40          conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 1, 10)     102410      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10)           0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           flatten_1[0][0]
# ==================================================================================================
# Total params: 1,538,247
# Trainable params: 1,536,691
# Non-trainable params: 1,556
# __________________________________________________________________________________________________

# %%
#Adding lr rate scheduling and model saving
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau

def lr_scheduler(epoch):
  lr = 1e-3
  if epoch > 80:
    lr *= 0.5e-3
  elif epoch > 60:
    lr *= 1e-3
  elif epoch > 40:
    lr *= 1e-2
  elif epoch > 20:
    lr *= 1e-1
  print('Learning rate: ', lr)
  return lr
  #return round(0.001 * 1/(1 + 0.319 * epoch), 10)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

filepath="/content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-{epoch:02d}-{val_acc:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

callback_list = [checkpoint, lr_reducer, LearningRateScheduler(lr_scheduler)]#[LearningRateScheduler(scheduler, verbose=1), checkpoint]

# Compile the model
model.compile(optimizer=Adam(lr=0.01), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0618 07:40:39.332111 140692701116288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# Training for Epochs = 100

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        rotation_range=15, width_shift_range=0.1, height_shift_range=0.1)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1, 
                                 callbacks=callback_list)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   from ipykernel import kernelapp as app
# W0618 07:40:43.820849 140692701116288 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# Learning rate:  0.001
# 390/390 [==============================] - 154s 396ms/step - loss: 1.6619 - acc: 0.4368 - val_loss: 1.7935 - val_acc: 0.4628
#
# Epoch 00001: val_acc improved from -inf to 0.46280, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-01-0.4628.hdf5
# Epoch 2/100
# Learning rate:  0.001
# 390/390 [==============================] - 148s 379ms/step - loss: 1.2130 - acc: 0.5742 - val_loss: 1.8294 - val_acc: 0.5126
#
# Epoch 00002: val_acc improved from 0.46280 to 0.51260, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-02-0.5126.hdf5
# Epoch 3/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 371ms/step - loss: 1.0627 - acc: 0.6253 - val_loss: 1.2443 - val_acc: 0.6155
#
# Epoch 00003: val_acc improved from 0.51260 to 0.61550, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-03-0.6155.hdf5
# Epoch 4/100
# Learning rate:  0.001
# 390/390 [==============================] - 145s 371ms/step - loss: 0.9502 - acc: 0.6679 - val_loss: 0.9750 - val_acc: 0.6863
#
# Epoch 00004: val_acc improved from 0.61550 to 0.68630, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-04-0.6863.hdf5
# Epoch 5/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 370ms/step - loss: 0.8746 - acc: 0.6959 - val_loss: 0.9811 - val_acc: 0.6820
#
# Epoch 00005: val_acc did not improve from 0.68630
# Epoch 6/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 370ms/step - loss: 0.8084 - acc: 0.7176 - val_loss: 1.3575 - val_acc: 0.6205
#
# Epoch 00006: val_acc did not improve from 0.68630
# Epoch 7/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 370ms/step - loss: 0.7632 - acc: 0.7333 - val_loss: 0.9364 - val_acc: 0.7076
#
# Epoch 00007: val_acc improved from 0.68630 to 0.70760, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-07-0.7076.hdf5
# Epoch 8/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 370ms/step - loss: 0.7186 - acc: 0.7494 - val_loss: 0.9579 - val_acc: 0.7070
#
# Epoch 00008: val_acc did not improve from 0.70760
# Epoch 9/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 370ms/step - loss: 0.6819 - acc: 0.7629 - val_loss: 0.7367 - val_acc: 0.7604
#
# Epoch 00009: val_acc improved from 0.70760 to 0.76040, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-09-0.7604.hdf5
# Epoch 10/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.6448 - acc: 0.7749 - val_loss: 0.7515 - val_acc: 0.7651
#
# Epoch 00010: val_acc improved from 0.76040 to 0.76510, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-10-0.7651.hdf5
# Epoch 11/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 370ms/step - loss: 0.6124 - acc: 0.7890 - val_loss: 0.7122 - val_acc: 0.7673
#
# Epoch 00011: val_acc improved from 0.76510 to 0.76730, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-11-0.7673.hdf5
# Epoch 12/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.5800 - acc: 0.7997 - val_loss: 0.8162 - val_acc: 0.7451
#
# Epoch 00012: val_acc did not improve from 0.76730
# Epoch 13/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.5539 - acc: 0.8100 - val_loss: 0.6638 - val_acc: 0.7849
#
# Epoch 00013: val_acc improved from 0.76730 to 0.78490, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-13-0.7849.hdf5
# Epoch 14/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 370ms/step - loss: 0.5260 - acc: 0.8176 - val_loss: 0.6805 - val_acc: 0.7857
#
# Epoch 00014: val_acc improved from 0.78490 to 0.78570, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-14-0.7857.hdf5
# Epoch 15/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 370ms/step - loss: 0.5047 - acc: 0.8258 - val_loss: 0.7430 - val_acc: 0.7665
#
# Epoch 00015: val_acc did not improve from 0.78570
# Epoch 16/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.4858 - acc: 0.8317 - val_loss: 0.6049 - val_acc: 0.7992
#
# Epoch 00016: val_acc improved from 0.78570 to 0.79920, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-16-0.7992.hdf5
# Epoch 17/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.4665 - acc: 0.8373 - val_loss: 0.6589 - val_acc: 0.7871
#
# Epoch 00017: val_acc did not improve from 0.79920
# Epoch 18/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.4505 - acc: 0.8445 - val_loss: 0.6111 - val_acc: 0.8033
#
# Epoch 00018: val_acc improved from 0.79920 to 0.80330, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-18-0.8033.hdf5
# Epoch 19/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.4310 - acc: 0.8516 - val_loss: 0.6246 - val_acc: 0.8118
#
# Epoch 00019: val_acc improved from 0.80330 to 0.81180, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-19-0.8118.hdf5
# Epoch 20/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 368ms/step - loss: 0.4103 - acc: 0.8590 - val_loss: 0.6397 - val_acc: 0.7954
#
# Epoch 00020: val_acc did not improve from 0.81180
# Epoch 21/100
# Learning rate:  0.001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.3978 - acc: 0.8604 - val_loss: 0.5930 - val_acc: 0.8131
#
# Epoch 00021: val_acc improved from 0.81180 to 0.81310, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-21-0.8131.hdf5
# Epoch 22/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 368ms/step - loss: 0.3260 - acc: 0.8874 - val_loss: 0.4509 - val_acc: 0.8537
#
# Epoch 00022: val_acc improved from 0.81310 to 0.85370, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-22-0.8537.hdf5
# Epoch 23/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2911 - acc: 0.9000 - val_loss: 0.4320 - val_acc: 0.8591
#
# Epoch 00023: val_acc improved from 0.85370 to 0.85910, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-23-0.8591.hdf5
# Epoch 24/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2764 - acc: 0.9060 - val_loss: 0.4334 - val_acc: 0.8621
#
# Epoch 00024: val_acc improved from 0.85910 to 0.86210, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-24-0.8621.hdf5
# Epoch 25/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2650 - acc: 0.9077 - val_loss: 0.4525 - val_acc: 0.8583
#
# Epoch 00025: val_acc did not improve from 0.86210
# Epoch 26/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2586 - acc: 0.9114 - val_loss: 0.4352 - val_acc: 0.8635
#
# Epoch 00026: val_acc improved from 0.86210 to 0.86350, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-26-0.8635.hdf5
# Epoch 27/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 368ms/step - loss: 0.2503 - acc: 0.9127 - val_loss: 0.4545 - val_acc: 0.8578
#
# Epoch 00027: val_acc did not improve from 0.86350
# Epoch 28/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2461 - acc: 0.9149 - val_loss: 0.4444 - val_acc: 0.8640
#
# Epoch 00028: val_acc improved from 0.86350 to 0.86400, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-28-0.8640.hdf5
# Epoch 29/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 368ms/step - loss: 0.2389 - acc: 0.9181 - val_loss: 0.4687 - val_acc: 0.8571
#
# Epoch 00029: val_acc did not improve from 0.86400
# Epoch 30/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2378 - acc: 0.9169 - val_loss: 0.4514 - val_acc: 0.8607
#
# Epoch 00030: val_acc did not improve from 0.86400
# Epoch 31/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2311 - acc: 0.9194 - val_loss: 0.4515 - val_acc: 0.8617
#
# Epoch 00031: val_acc did not improve from 0.86400
# Epoch 32/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2289 - acc: 0.9208 - val_loss: 0.4485 - val_acc: 0.8627
#
# Epoch 00032: val_acc did not improve from 0.86400
# Epoch 33/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2241 - acc: 0.9219 - val_loss: 0.4342 - val_acc: 0.8656
#
# Epoch 00033: val_acc improved from 0.86400 to 0.86560, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-33-0.8656.hdf5
# Epoch 34/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2186 - acc: 0.9248 - val_loss: 0.4657 - val_acc: 0.8595
#
# Epoch 00034: val_acc did not improve from 0.86560
# Epoch 35/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2134 - acc: 0.9265 - val_loss: 0.4557 - val_acc: 0.8626
#
# Epoch 00035: val_acc did not improve from 0.86560
# Epoch 36/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2154 - acc: 0.9251 - val_loss: 0.4749 - val_acc: 0.8609
#
# Epoch 00036: val_acc did not improve from 0.86560
# Epoch 37/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2074 - acc: 0.9274 - val_loss: 0.4776 - val_acc: 0.8604
#
# Epoch 00037: val_acc did not improve from 0.86560
# Epoch 38/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2067 - acc: 0.9279 - val_loss: 0.4523 - val_acc: 0.8653
#
# Epoch 00038: val_acc did not improve from 0.86560
# Epoch 39/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.2031 - acc: 0.9285 - val_loss: 0.4623 - val_acc: 0.8614
#
# Epoch 00039: val_acc did not improve from 0.86560
# Epoch 40/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1965 - acc: 0.9323 - val_loss: 0.4624 - val_acc: 0.8630
#
# Epoch 00040: val_acc did not improve from 0.86560
# Epoch 41/100
# Learning rate:  0.0001
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1999 - acc: 0.9306 - val_loss: 0.4752 - val_acc: 0.8614
#
# Epoch 00041: val_acc did not improve from 0.86560
# Epoch 42/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1897 - acc: 0.9337 - val_loss: 0.4537 - val_acc: 0.8644
#
# Epoch 00042: val_acc did not improve from 0.86560
# Epoch 43/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1836 - acc: 0.9359 - val_loss: 0.4497 - val_acc: 0.8660
#
# Epoch 00043: val_acc improved from 0.86560 to 0.86600, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-43-0.8660.hdf5
# Epoch 44/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1820 - acc: 0.9363 - val_loss: 0.4537 - val_acc: 0.8647
#
# Epoch 00044: val_acc did not improve from 0.86600
# Epoch 45/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1799 - acc: 0.9367 - val_loss: 0.4509 - val_acc: 0.8662
#
# Epoch 00045: val_acc improved from 0.86600 to 0.86620, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-45-0.8662.hdf5
# Epoch 46/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1781 - acc: 0.9375 - val_loss: 0.4522 - val_acc: 0.8652
#
# Epoch 00046: val_acc did not improve from 0.86620
# Epoch 47/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 368ms/step - loss: 0.1798 - acc: 0.9376 - val_loss: 0.4517 - val_acc: 0.8661
#
# Epoch 00047: val_acc did not improve from 0.86620
# Epoch 48/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1771 - acc: 0.9390 - val_loss: 0.4526 - val_acc: 0.8665
#
# Epoch 00048: val_acc improved from 0.86620 to 0.86650, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-48-0.8665.hdf5
# Epoch 49/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1753 - acc: 0.9382 - val_loss: 0.4555 - val_acc: 0.8658
#
# Epoch 00049: val_acc did not improve from 0.86650
# Epoch 50/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 368ms/step - loss: 0.1757 - acc: 0.9385 - val_loss: 0.4564 - val_acc: 0.8654
#
# Epoch 00050: val_acc did not improve from 0.86650
# Epoch 51/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1740 - acc: 0.9396 - val_loss: 0.4571 - val_acc: 0.8652
#
# Epoch 00051: val_acc did not improve from 0.86650
# Epoch 52/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1770 - acc: 0.9393 - val_loss: 0.4519 - val_acc: 0.8666
#
# Epoch 00052: val_acc improved from 0.86650 to 0.86660, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v5_final_weights-improvement-52-0.8666.hdf5
# Epoch 53/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 368ms/step - loss: 0.1734 - acc: 0.9396 - val_loss: 0.4566 - val_acc: 0.8653
#
# Epoch 00053: val_acc did not improve from 0.86660
# Epoch 54/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1731 - acc: 0.9389 - val_loss: 0.4600 - val_acc: 0.8652
#
# Epoch 00054: val_acc did not improve from 0.86660
# Epoch 55/100
# Learning rate:  1e-05
# 390/390 [==============================] - 143s 368ms/step - loss: 0.1756 - acc: 0.9388 - val_loss: 0.4544 - val_acc: 0.8662
#
# Epoch 00055: val_acc did not improve from 0.86660
# Epoch 56/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1718 - acc: 0.9412 - val_loss: 0.4551 - val_acc: 0.8663
#
# Epoch 00056: val_acc did not improve from 0.86660
# Epoch 57/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1732 - acc: 0.9392 - val_loss: 0.4595 - val_acc: 0.8657
#
# Epoch 00057: val_acc did not improve from 0.86660
# Epoch 58/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 368ms/step - loss: 0.1723 - acc: 0.9410 - val_loss: 0.4606 - val_acc: 0.8653
#
# Epoch 00058: val_acc did not improve from 0.86660
# Epoch 59/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1694 - acc: 0.9401 - val_loss: 0.4583 - val_acc: 0.8646
#
# Epoch 00059: val_acc did not improve from 0.86660
# Epoch 60/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1715 - acc: 0.9404 - val_loss: 0.4554 - val_acc: 0.8664
#
# Epoch 00060: val_acc did not improve from 0.86660
# Epoch 61/100
# Learning rate:  1e-05
# 390/390 [==============================] - 144s 368ms/step - loss: 0.1688 - acc: 0.9413 - val_loss: 0.4607 - val_acc: 0.8642
#
# Epoch 00061: val_acc did not improve from 0.86660
# Epoch 62/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 368ms/step - loss: 0.1670 - acc: 0.9412 - val_loss: 0.4606 - val_acc: 0.8646
#
# Epoch 00062: val_acc did not improve from 0.86660
# Epoch 63/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1673 - acc: 0.9417 - val_loss: 0.4610 - val_acc: 0.8646
#
# Epoch 00063: val_acc did not improve from 0.86660
# Epoch 64/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1716 - acc: 0.9415 - val_loss: 0.4602 - val_acc: 0.8647
#
# Epoch 00064: val_acc did not improve from 0.86660
# Epoch 65/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 368ms/step - loss: 0.1692 - acc: 0.9407 - val_loss: 0.4630 - val_acc: 0.8648
#
# Epoch 00065: val_acc did not improve from 0.86660
# Epoch 66/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1690 - acc: 0.9421 - val_loss: 0.4608 - val_acc: 0.8644
#
# Epoch 00066: val_acc did not improve from 0.86660
# Epoch 67/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1720 - acc: 0.9402 - val_loss: 0.4602 - val_acc: 0.8652
#
# Epoch 00067: val_acc did not improve from 0.86660
# Epoch 68/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1671 - acc: 0.9422 - val_loss: 0.4600 - val_acc: 0.8652
#
# Epoch 00068: val_acc did not improve from 0.86660
# Epoch 69/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1698 - acc: 0.9408 - val_loss: 0.4588 - val_acc: 0.8658
#
# Epoch 00069: val_acc did not improve from 0.86660
# Epoch 70/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1692 - acc: 0.9415 - val_loss: 0.4600 - val_acc: 0.8653
#
# Epoch 00070: val_acc did not improve from 0.86660
# Epoch 71/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1717 - acc: 0.9397 - val_loss: 0.4599 - val_acc: 0.8657
#
# Epoch 00071: val_acc did not improve from 0.86660
# Epoch 72/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 368ms/step - loss: 0.1707 - acc: 0.9412 - val_loss: 0.4606 - val_acc: 0.8652
#
# Epoch 00072: val_acc did not improve from 0.86660
# Epoch 73/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1697 - acc: 0.9401 - val_loss: 0.4615 - val_acc: 0.8649
#
# Epoch 00073: val_acc did not improve from 0.86660
# Epoch 74/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1724 - acc: 0.9402 - val_loss: 0.4618 - val_acc: 0.8646
#
# Epoch 00074: val_acc did not improve from 0.86660
# Epoch 75/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1662 - acc: 0.9427 - val_loss: 0.4622 - val_acc: 0.8653
#
# Epoch 00075: val_acc did not improve from 0.86660
# Epoch 76/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1705 - acc: 0.9400 - val_loss: 0.4619 - val_acc: 0.8649
#
# Epoch 00076: val_acc did not improve from 0.86660
# Epoch 77/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1703 - acc: 0.9404 - val_loss: 0.4601 - val_acc: 0.8648
#
# Epoch 00077: val_acc did not improve from 0.86660
# Epoch 78/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1718 - acc: 0.9400 - val_loss: 0.4623 - val_acc: 0.8653
#
# Epoch 00078: val_acc did not improve from 0.86660
# Epoch 79/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1674 - acc: 0.9418 - val_loss: 0.4629 - val_acc: 0.8653
#
# Epoch 00079: val_acc did not improve from 0.86660
# Epoch 80/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1621 - acc: 0.9433 - val_loss: 0.4627 - val_acc: 0.8653
#
# Epoch 00080: val_acc did not improve from 0.86660
# Epoch 81/100
# Learning rate:  1e-06
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1677 - acc: 0.9417 - val_loss: 0.4610 - val_acc: 0.8653
#
# Epoch 00081: val_acc did not improve from 0.86660
# Epoch 82/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1673 - acc: 0.9411 - val_loss: 0.4609 - val_acc: 0.8658
#
# Epoch 00082: val_acc did not improve from 0.86660
# Epoch 83/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1632 - acc: 0.9433 - val_loss: 0.4611 - val_acc: 0.8657
#
# Epoch 00083: val_acc did not improve from 0.86660
# Epoch 84/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1706 - acc: 0.9406 - val_loss: 0.4613 - val_acc: 0.8661
#
# Epoch 00084: val_acc did not improve from 0.86660
# Epoch 85/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1664 - acc: 0.9419 - val_loss: 0.4617 - val_acc: 0.8651
#
# Epoch 00085: val_acc did not improve from 0.86660
# Epoch 86/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1714 - acc: 0.9408 - val_loss: 0.4615 - val_acc: 0.8646
#
# Epoch 00086: val_acc did not improve from 0.86660
# Epoch 87/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1707 - acc: 0.9409 - val_loss: 0.4596 - val_acc: 0.8654
#
# Epoch 00087: val_acc did not improve from 0.86660
# Epoch 88/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1693 - acc: 0.9427 - val_loss: 0.4624 - val_acc: 0.8651
#
# Epoch 00088: val_acc did not improve from 0.86660
# Epoch 89/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1724 - acc: 0.9404 - val_loss: 0.4630 - val_acc: 0.8654
#
# Epoch 00089: val_acc did not improve from 0.86660
# Epoch 90/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1679 - acc: 0.9409 - val_loss: 0.4629 - val_acc: 0.8651
#
# Epoch 00090: val_acc did not improve from 0.86660
# Epoch 91/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1709 - acc: 0.9414 - val_loss: 0.4623 - val_acc: 0.8651
#
# Epoch 00091: val_acc did not improve from 0.86660
# Epoch 92/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1675 - acc: 0.9409 - val_loss: 0.4618 - val_acc: 0.8649
#
# Epoch 00092: val_acc did not improve from 0.86660
# Epoch 93/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1717 - acc: 0.9408 - val_loss: 0.4614 - val_acc: 0.8653
#
# Epoch 00093: val_acc did not improve from 0.86660
# Epoch 94/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1655 - acc: 0.9421 - val_loss: 0.4615 - val_acc: 0.8650
#
# Epoch 00094: val_acc did not improve from 0.86660
# Epoch 95/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1706 - acc: 0.9399 - val_loss: 0.4609 - val_acc: 0.8660
#
# Epoch 00095: val_acc did not improve from 0.86660
# Epoch 96/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1675 - acc: 0.9413 - val_loss: 0.4624 - val_acc: 0.8646
#
# Epoch 00096: val_acc did not improve from 0.86660
# Epoch 97/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1675 - acc: 0.9411 - val_loss: 0.4628 - val_acc: 0.8647
#
# Epoch 00097: val_acc did not improve from 0.86660
# Epoch 98/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 370ms/step - loss: 0.1670 - acc: 0.9416 - val_loss: 0.4606 - val_acc: 0.8653
#
# Epoch 00098: val_acc did not improve from 0.86660
# Epoch 99/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1661 - acc: 0.9416 - val_loss: 0.4605 - val_acc: 0.8654
#
# Epoch 00099: val_acc did not improve from 0.86660
# Epoch 100/100
# Learning rate:  5e-07
# 390/390 [==============================] - 144s 369ms/step - loss: 0.1655 - acc: 0.9428 - val_loss: 0.4609 - val_acc: 0.8656
#
# Epoch 00100: val_acc did not improve from 0.86660
# Model took 14422.25 seconds to train
# Accuracy on test data is: 86.56
