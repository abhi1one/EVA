# %% [markdown]
# Session 7 Task 2
#
# Problem statement:
# Design this network (CIFAR10):
# 1. Image result for eNAS network architecture
# 2. The lines you see are the skip-connections. You need to add them
# 3. Train for 100 Epochs (add BN and ReLU after every layer)
# 4. Submit the results

# %% [markdown]
# Importing al necessary keras, matplot, numpy libs

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, SeparableConv2D, DepthwiseConv2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
#preparing check point for saving weights via callback
from google.colab import drive
from keras.callbacks import CSVLogger
from keras.callbacks import ModelCheckpoint

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Importing, loading data in train and test

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %% [markdown]
# Viewsing train data for labels.

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# Defigning function to plot model training validation accuracy and loss

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# Defining function to find and return accracy of trained model in percentage

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# Normalizing train and test data
# Converting labels from 1-D to 2-D with leangth of second dimention is num_class

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# Defining ENAS network arch
# Removing dense

# %%
#Defining model

#importing necessary modules
from keras.models import Model
from keras.layers import Input, Flatten, Conv2D
from keras.layers.merge import concatenate

# input layer
visible = Input(shape=(32,32,3))

# layer1 Sep 5x5 
layer1 = SeparableConv2D(32, (5, 5), padding="same", activation='relu') (visible)
layer1 = (BatchNormalization())(layer1) 

# layer2 conv 5x5
layer2 = Conv2D(32, (5, 5), padding="same", activation='relu') (layer1)
layer2 = (BatchNormalization())(layer2) 

# layer3 conv 5x5
layer3 = Conv2D(32, (5, 5), padding="same", activation='relu') (layer2)
layer3 = (BatchNormalization())(layer3) 

# layer4 Sep 5x5 from 1
layer4 = SeparableConv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer3]))
layer4 = (BatchNormalization())(layer4) 

# pool1 maxpooling skip from 1
btl_nek1 = Conv2D(48, (1, 1), padding="same", activation='relu') (concatenate([layer1, layer4]))
pool1 = MaxPooling2D(pool_size=(2, 2), padding="same", strides=1) (btl_nek1)

# layer5 sep 3x3 
layer5 = SeparableConv2D(32, (3, 3), padding="same", activation='relu') (pool1)
layer5 = (BatchNormalization())(layer5) 

# layer6 conv 5x5 skip from 1,4
layer6 = Conv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer4, layer5]))
layer6 = (BatchNormalization())(layer6) 

# layer7 sep 3x3 skip from 3,4,5
layer7 = SeparableConv2D(32, (3, 1), padding="same", activation='relu') (concatenate([layer3, layer4, layer5, layer6]))
layer7 = (BatchNormalization())(layer7) 

# layer8 sep 5x5 skip from 1,3,4,5,6
layer8 = SeparableConv2D(32, (3, 3), padding="same", activation='relu') (concatenate([layer1, layer3, layer4, layer5, layer6, layer7]))
layer8 = (BatchNormalization())(layer8) 

# pool2 maxpooling skip from 1,4,5,7
btl_nek10 = Conv2D(128, (1, 1), padding="same", activation='relu') (concatenate([layer1, layer4, layer5, layer7, layer8]))
pool2 = MaxPooling2D(pool_size=(2, 2), padding="same", strides=1) (btl_nek10)

# layer9 conv 5x5 skip from 6
layer9 = Conv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer6, pool2]))
layer9 = (BatchNormalization())(layer9) 

# layer10 sep 5x5 skip from 1,2,4,7
layer10 = SeparableConv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer1, layer2, layer4, layer7, layer9]))
layer10 = (BatchNormalization())(layer10) 

# layer11 conv 3x3 skip from 2,3,5,9
layer11 = Conv2D(32, (3, 3), padding="same", activation='relu') (concatenate([layer2, layer3, layer5, layer9, layer10]))
layer11 = (BatchNormalization())(layer11) 
  
# layer12 sep 5x5 skip from 3,4,5,7,10
layer12 = SeparableConv2D(32, (5, 5), padding="same", activation='relu') (concatenate([layer3, layer4, layer5, layer7, layer10, layer11]))
layer12 = (BatchNormalization())(layer12) 

# last part skip from 4,8,12
btl_nck3 = Convolution2D(10, 1, padding="same", activation='relu')(concatenate([layer4, layer7, layer10, layer12]))
btl_nck3 = (BatchNormalization())(btl_nck3) 

last = Convolution2D(10, 32)(btl_nck3)
output = Flatten() (last)
output = (Activation('softmax')) (output)


model = Model(inputs=visible, outputs=output)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_36 (SeparableC (None, 32, 32, 32)   203         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 32)   25632       batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 32)   128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 32)   25632       batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 32)   128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 32, 32, 64)   0           batch_normalization_62[0][0]
#                                                                  batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_37 (SeparableC (None, 32, 32, 32)   3680        concatenate_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 32, 32, 64)   0           batch_normalization_62[0][0]
#                                                                  batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 48)   3120        concatenate_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 48)   0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_38 (SeparableC (None, 32, 32, 32)   2000        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 32, 32, 96)   0           batch_normalization_62[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 32)   76832       concatenate_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 32)   128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 32, 32, 128)  0           batch_normalization_64[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
#                                                                  batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_39 (SeparableC (None, 32, 32, 32)   4512        concatenate_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 32, 32, 192)  0           batch_normalization_62[0][0]
#                                                                  batch_normalization_64[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
#                                                                  batch_normalization_67[0][0]
#                                                                  batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_40 (SeparableC (None, 32, 32, 32)   7904        concatenate_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 32, 32, 160)  0           batch_normalization_62[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
#                                                                  batch_normalization_68[0][0]
#                                                                  batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 128)  20608       concatenate_61[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 32, 32, 160)  0           batch_normalization_67[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 32)   128032      concatenate_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 32, 32, 32)   128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 32, 32, 160)  0           batch_normalization_62[0][0]
#                                                                  batch_normalization_63[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_68[0][0]
#                                                                  batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_41 (SeparableC (None, 32, 32, 32)   9152        concatenate_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_41[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 32, 32, 160)  0           batch_normalization_63[0][0]
#                                                                  batch_normalization_64[0][0]
#                                                                  batch_normalization_66[0][0]
#                                                                  batch_normalization_70[0][0]
#                                                                  batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 32)   46112       concatenate_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 32, 32, 32)   128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 32, 32, 192)  0           batch_normalization_64[0][0]
#                                                                  batch_normalization_65[0][0]
#                                                                  batch_normalization_66[0][0]
#                                                                  batch_normalization_68[0][0]
#                                                                  batch_normalization_71[0][0]
#                                                                  batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_42 (SeparableC (None, 32, 32, 32)   10976       concatenate_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 32, 32, 128)  0           batch_normalization_65[0][0]
#                                                                  batch_normalization_68[0][0]
#                                                                  batch_normalization_71[0][0]
#                                                                  batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 10)   1290        concatenate_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 32, 32, 10)   40          conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 1, 1, 10)     102410      batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 10)           0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           flatten_6[0][0]
# ==================================================================================================
# Total params: 469,671
# Trainable params: 468,883
# Non-trainable params: 788
# __________________________________________________________________________________________________

# %%
#Adding lr rate scheduling and model saving
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau

def lr_scheduler(epoch):
  lr = 1e-3
  if epoch > 80:
    lr *= 0.5e-3
  elif epoch > 60:
    lr *= 1e-3
  elif epoch > 40:
    lr *= 1e-2
  elif epoch > 20:
    lr *= 1e-1
  print('Learning rate: ', lr)
  return lr
  #return round(0.001 * 1/(1 + 0.319 * epoch), 10)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

filepath="/content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-{epoch:02d}-{val_acc:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

callback_list = [checkpoint, lr_reducer, LearningRateScheduler(lr_scheduler)]#[LearningRateScheduler(scheduler, verbose=1), checkpoint]

# Compile the model
model.compile(optimizer=Adam(lr=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Training for Epochs = 100

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        rotation_range=15, width_shift_range=0.1, height_shift_range=0.1)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1, 
                                 callbacks=callback_list)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   from ipykernel import kernelapp as app
# Epoch 1/100
# Learning rate:  0.001
# 390/390 [==============================] - 161s 412ms/step - loss: 1.6713 - acc: 0.4305 - val_loss: 2.4823 - val_acc: 0.3661
#
# Epoch 00001: val_acc improved from -inf to 0.36610, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-01-0.3661.hdf5
# Epoch 2/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 386ms/step - loss: 1.2660 - acc: 0.5538 - val_loss: 1.3990 - val_acc: 0.5645
#
# Epoch 00002: val_acc improved from 0.36610 to 0.56450, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-02-0.5645.hdf5
# Epoch 3/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 386ms/step - loss: 1.1180 - acc: 0.6061 - val_loss: 1.3477 - val_acc: 0.5774
#
# Epoch 00003: val_acc improved from 0.56450 to 0.57740, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-03-0.5774.hdf5
# Epoch 4/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 1.0139 - acc: 0.6444 - val_loss: 1.1881 - val_acc: 0.6139
#
# Epoch 00004: val_acc improved from 0.57740 to 0.61390, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-04-0.6139.hdf5
# Epoch 5/100
# Learning rate:  0.001
# 390/390 [==============================] - 151s 387ms/step - loss: 0.9518 - acc: 0.6642 - val_loss: 1.1815 - val_acc: 0.6354
#
# Epoch 00005: val_acc improved from 0.61390 to 0.63540, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-05-0.6354.hdf5
# Epoch 6/100
# Learning rate:  0.001
# 390/390 [==============================] - 151s 386ms/step - loss: 0.8897 - acc: 0.6880 - val_loss: 0.9325 - val_acc: 0.6946
#
# Epoch 00006: val_acc improved from 0.63540 to 0.69460, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-06-0.6946.hdf5
# Epoch 7/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 386ms/step - loss: 0.8424 - acc: 0.7034 - val_loss: 0.9448 - val_acc: 0.6944
#
# Epoch 00007: val_acc did not improve from 0.69460
# Epoch 8/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.8094 - acc: 0.7145 - val_loss: 0.9403 - val_acc: 0.6932
#
# Epoch 00008: val_acc did not improve from 0.69460
# Epoch 9/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.7740 - acc: 0.7273 - val_loss: 0.8701 - val_acc: 0.7062
#
# Epoch 00009: val_acc improved from 0.69460 to 0.70620, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-09-0.7062.hdf5
# Epoch 10/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.7455 - acc: 0.7385 - val_loss: 0.7608 - val_acc: 0.7409
#
# Epoch 00010: val_acc improved from 0.70620 to 0.74090, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-10-0.7409.hdf5
# Epoch 11/100
# Learning rate:  0.001
# 390/390 [==============================] - 151s 387ms/step - loss: 0.7147 - acc: 0.7506 - val_loss: 0.9132 - val_acc: 0.7155
#
# Epoch 00011: val_acc did not improve from 0.74090
# Epoch 12/100
# Learning rate:  0.001
# 390/390 [==============================] - 151s 386ms/step - loss: 0.6970 - acc: 0.7574 - val_loss: 0.9662 - val_acc: 0.6961
#
# Epoch 00012: val_acc did not improve from 0.74090
# Epoch 13/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 384ms/step - loss: 0.6721 - acc: 0.7661 - val_loss: 0.7658 - val_acc: 0.7442
#
# Epoch 00013: val_acc improved from 0.74090 to 0.74420, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-13-0.7442.hdf5
# Epoch 14/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.6516 - acc: 0.7743 - val_loss: 0.8771 - val_acc: 0.7300
#
# Epoch 00014: val_acc did not improve from 0.74420
# Epoch 15/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.6374 - acc: 0.7789 - val_loss: 0.7849 - val_acc: 0.7444
#
# Epoch 00015: val_acc improved from 0.74420 to 0.74440, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-15-0.7444.hdf5
# Epoch 16/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.6183 - acc: 0.7852 - val_loss: 0.6933 - val_acc: 0.7696
#
# Epoch 00016: val_acc improved from 0.74440 to 0.76960, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-16-0.7696.hdf5
# Epoch 17/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 386ms/step - loss: 0.5996 - acc: 0.7906 - val_loss: 0.9853 - val_acc: 0.7023
#
# Epoch 00017: val_acc did not improve from 0.76960
# Epoch 18/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.5900 - acc: 0.7950 - val_loss: 1.1136 - val_acc: 0.6825
#
# Epoch 00018: val_acc did not improve from 0.76960
# Epoch 19/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 384ms/step - loss: 0.5740 - acc: 0.8010 - val_loss: 0.6793 - val_acc: 0.7771
#
# Epoch 00019: val_acc improved from 0.76960 to 0.77710, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-19-0.7771.hdf5
# Epoch 20/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.5618 - acc: 0.8057 - val_loss: 0.7676 - val_acc: 0.7588
#
# Epoch 00020: val_acc did not improve from 0.77710
# Epoch 21/100
# Learning rate:  0.001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.5492 - acc: 0.8093 - val_loss: 0.7175 - val_acc: 0.7711
#
# Epoch 00021: val_acc did not improve from 0.77710
# Epoch 22/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.4784 - acc: 0.8353 - val_loss: 0.5507 - val_acc: 0.8176
#
# Epoch 00022: val_acc improved from 0.77710 to 0.81760, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-22-0.8176.hdf5
# Epoch 23/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 386ms/step - loss: 0.4537 - acc: 0.8415 - val_loss: 0.5275 - val_acc: 0.8247
#
# Epoch 00023: val_acc improved from 0.81760 to 0.82470, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-23-0.8247.hdf5
# Epoch 24/100
# Learning rate:  0.0001
# 390/390 [==============================] - 151s 386ms/step - loss: 0.4449 - acc: 0.8455 - val_loss: 0.5541 - val_acc: 0.8168
#
# Epoch 00024: val_acc did not improve from 0.82470
# Epoch 25/100
# Learning rate:  0.0001
# 390/390 [==============================] - 151s 386ms/step - loss: 0.4323 - acc: 0.8495 - val_loss: 0.5496 - val_acc: 0.8182
#
# Epoch 00025: val_acc did not improve from 0.82470
# Epoch 26/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 386ms/step - loss: 0.4304 - acc: 0.8497 - val_loss: 0.5230 - val_acc: 0.8277
#
# Epoch 00026: val_acc improved from 0.82470 to 0.82770, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-26-0.8277.hdf5
# Epoch 27/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.4258 - acc: 0.8538 - val_loss: 0.5288 - val_acc: 0.8262
#
# Epoch 00027: val_acc did not improve from 0.82770
# Epoch 28/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.4199 - acc: 0.8541 - val_loss: 0.5560 - val_acc: 0.8187
#
# Epoch 00028: val_acc did not improve from 0.82770
# Epoch 29/100
# Learning rate:  0.0001
# 390/390 [==============================] - 151s 386ms/step - loss: 0.4168 - acc: 0.8559 - val_loss: 0.5428 - val_acc: 0.8222
#
# Epoch 00029: val_acc did not improve from 0.82770
# Epoch 30/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 386ms/step - loss: 0.4145 - acc: 0.8558 - val_loss: 0.5336 - val_acc: 0.8241
#
# Epoch 00030: val_acc did not improve from 0.82770
# Epoch 31/100
# Learning rate:  0.0001
# 390/390 [==============================] - 151s 387ms/step - loss: 0.4010 - acc: 0.8618 - val_loss: 0.5121 - val_acc: 0.8333
#
# Epoch 00031: val_acc improved from 0.82770 to 0.83330, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-31-0.8333.hdf5
# Epoch 32/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.4042 - acc: 0.8604 - val_loss: 0.5308 - val_acc: 0.8258
#
# Epoch 00032: val_acc did not improve from 0.83330
# Epoch 33/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.4012 - acc: 0.8607 - val_loss: 0.5546 - val_acc: 0.8199
#
# Epoch 00033: val_acc did not improve from 0.83330
# Epoch 34/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3957 - acc: 0.8617 - val_loss: 0.5493 - val_acc: 0.8198
#
# Epoch 00034: val_acc did not improve from 0.83330
# Epoch 35/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3980 - acc: 0.8607 - val_loss: 0.5226 - val_acc: 0.8312
#
# Epoch 00035: val_acc did not improve from 0.83330
# Epoch 36/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3897 - acc: 0.8645 - val_loss: 0.5391 - val_acc: 0.8252
#
# Epoch 00036: val_acc did not improve from 0.83330
# Epoch 37/100
# Learning rate:  0.0001
# 390/390 [==============================] - 151s 386ms/step - loss: 0.3828 - acc: 0.8683 - val_loss: 0.5430 - val_acc: 0.8252
#
# Epoch 00037: val_acc did not improve from 0.83330
# Epoch 38/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 384ms/step - loss: 0.3838 - acc: 0.8673 - val_loss: 0.5135 - val_acc: 0.8346
#
# Epoch 00038: val_acc improved from 0.83330 to 0.83460, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-38-0.8346.hdf5
# Epoch 39/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 386ms/step - loss: 0.3833 - acc: 0.8667 - val_loss: 0.5343 - val_acc: 0.8290
#
# Epoch 00039: val_acc did not improve from 0.83460
# Epoch 40/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3837 - acc: 0.8668 - val_loss: 0.5176 - val_acc: 0.8349
#
# Epoch 00040: val_acc improved from 0.83460 to 0.83490, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-40-0.8349.hdf5
# Epoch 41/100
# Learning rate:  0.0001
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3731 - acc: 0.8700 - val_loss: 0.5284 - val_acc: 0.8317
#
# Epoch 00041: val_acc did not improve from 0.83490
# Epoch 42/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 386ms/step - loss: 0.3726 - acc: 0.8703 - val_loss: 0.5229 - val_acc: 0.8316
#
# Epoch 00042: val_acc did not improve from 0.83490
# Epoch 43/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3676 - acc: 0.8723 - val_loss: 0.5214 - val_acc: 0.8331
#
# Epoch 00043: val_acc did not improve from 0.83490
# Epoch 44/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3669 - acc: 0.8733 - val_loss: 0.5215 - val_acc: 0.8331
#
# Epoch 00044: val_acc did not improve from 0.83490
# Epoch 45/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3620 - acc: 0.8744 - val_loss: 0.5226 - val_acc: 0.8330
#
# Epoch 00045: val_acc did not improve from 0.83490
# Epoch 46/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3659 - acc: 0.8734 - val_loss: 0.5226 - val_acc: 0.8325
#
# Epoch 00046: val_acc did not improve from 0.83490
# Epoch 47/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 384ms/step - loss: 0.3619 - acc: 0.8753 - val_loss: 0.5259 - val_acc: 0.8330
#
# Epoch 00047: val_acc did not improve from 0.83490
# Epoch 48/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 386ms/step - loss: 0.3671 - acc: 0.8719 - val_loss: 0.5196 - val_acc: 0.8343
#
# Epoch 00048: val_acc did not improve from 0.83490
# Epoch 49/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3600 - acc: 0.8758 - val_loss: 0.5212 - val_acc: 0.8340
#
# Epoch 00049: val_acc did not improve from 0.83490
# Epoch 50/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3658 - acc: 0.8713 - val_loss: 0.5206 - val_acc: 0.8343
#
# Epoch 00050: val_acc did not improve from 0.83490
# Epoch 51/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3573 - acc: 0.8760 - val_loss: 0.5218 - val_acc: 0.8340
#
# Epoch 00051: val_acc did not improve from 0.83490
# Epoch 52/100
# Learning rate:  1e-05
# 390/390 [==============================] - 151s 386ms/step - loss: 0.3630 - acc: 0.8748 - val_loss: 0.5177 - val_acc: 0.8342
#
# Epoch 00052: val_acc did not improve from 0.83490
# Epoch 53/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3595 - acc: 0.8752 - val_loss: 0.5211 - val_acc: 0.8334
#
# Epoch 00053: val_acc did not improve from 0.83490
# Epoch 54/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3599 - acc: 0.8747 - val_loss: 0.5233 - val_acc: 0.8333
#
# Epoch 00054: val_acc did not improve from 0.83490
# Epoch 55/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3627 - acc: 0.8743 - val_loss: 0.5161 - val_acc: 0.8356
#
# Epoch 00055: val_acc improved from 0.83490 to 0.83560, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-55-0.8356.hdf5
# Epoch 56/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3573 - acc: 0.8753 - val_loss: 0.5186 - val_acc: 0.8340
#
# Epoch 00056: val_acc did not improve from 0.83560
# Epoch 57/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3607 - acc: 0.8731 - val_loss: 0.5207 - val_acc: 0.8346
#
# Epoch 00057: val_acc did not improve from 0.83560
# Epoch 58/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 386ms/step - loss: 0.3567 - acc: 0.8766 - val_loss: 0.5196 - val_acc: 0.8344
#
# Epoch 00058: val_acc did not improve from 0.83560
# Epoch 59/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3548 - acc: 0.8775 - val_loss: 0.5209 - val_acc: 0.8353
#
# Epoch 00059: val_acc did not improve from 0.83560
# Epoch 60/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3576 - acc: 0.8767 - val_loss: 0.5219 - val_acc: 0.8350
#
# Epoch 00060: val_acc did not improve from 0.83560
# Epoch 61/100
# Learning rate:  1e-05
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3599 - acc: 0.8760 - val_loss: 0.5172 - val_acc: 0.8357
#
# Epoch 00061: val_acc improved from 0.83560 to 0.83570, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-61-0.8357.hdf5
# Epoch 62/100
# Learning rate:  1e-06
# 390/390 [==============================] - 150s 386ms/step - loss: 0.3530 - acc: 0.8753 - val_loss: 0.5186 - val_acc: 0.8355
#
# Epoch 00062: val_acc did not improve from 0.83570
# Epoch 63/100
# Learning rate:  1e-06
# 390/390 [==============================] - 151s 386ms/step - loss: 0.3587 - acc: 0.8761 - val_loss: 0.5194 - val_acc: 0.8354
#
# Epoch 00063: val_acc did not improve from 0.83570
# Epoch 64/100
# Learning rate:  1e-06
# 390/390 [==============================] - 150s 384ms/step - loss: 0.3602 - acc: 0.8755 - val_loss: 0.5217 - val_acc: 0.8346
#
# Epoch 00064: val_acc did not improve from 0.83570
# Epoch 65/100
# Learning rate:  1e-06
# 390/390 [==============================] - 150s 384ms/step - loss: 0.3555 - acc: 0.8749 - val_loss: 0.5212 - val_acc: 0.8350
#
# Epoch 00065: val_acc did not improve from 0.83570
# Epoch 66/100
# Learning rate:  1e-06
# 390/390 [==============================] - 150s 386ms/step - loss: 0.3553 - acc: 0.8766 - val_loss: 0.5212 - val_acc: 0.8346
#
# Epoch 00066: val_acc did not improve from 0.83570
# Epoch 67/100
# Learning rate:  1e-06
# 390/390 [==============================] - 150s 385ms/step - loss: 0.3562 - acc: 0.8757 - val_loss: 0.5205 - val_acc: 0.8346
#
# Epoch 00067: val_acc did not improve from 0.83570
# Epoch 68/100
# Learning rate:  1e-06
# 390/390 [==============================] - 150s 384ms/step - loss: 0.3586 - acc: 0.8751 - val_loss: 0.5207 - val_acc: 0.8353
#
# Epoch 00068: val_acc did not improve from 0.83570
# Epoch 69/100
# Learning rate:  1e-06
# 390/390 [==============================] - 150s 386ms/step - loss: 0.3578 - acc: 0.8764 - val_loss: 0.5190 - val_acc: 0.8353
#
# Epoch 00069: val_acc did not improve from 0.83570
# Epoch 70/100
# Learning rate:  1e-06
# 390/390 [==============================] - 89s 227ms/step - loss: 0.3537 - acc: 0.8768 - val_loss: 0.5191 - val_acc: 0.8358
#
# Epoch 00070: val_acc improved from 0.83570 to 0.83580, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-70-0.8358.hdf5
# Epoch 71/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 182ms/step - loss: 0.3544 - acc: 0.8761 - val_loss: 0.5205 - val_acc: 0.8360
#
# Epoch 00071: val_acc improved from 0.83580 to 0.83600, saving model to /content/gdrive/My Drive/Weights/Session7Task2-v4_final_weights-improvement-71-0.8360.hdf5
# Epoch 72/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3562 - acc: 0.8757 - val_loss: 0.5194 - val_acc: 0.8349
#
# Epoch 00072: val_acc did not improve from 0.83600
# Epoch 73/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3496 - acc: 0.8767 - val_loss: 0.5209 - val_acc: 0.8352
#
# Epoch 00073: val_acc did not improve from 0.83600
# Epoch 74/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3568 - acc: 0.8741 - val_loss: 0.5214 - val_acc: 0.8348
#
# Epoch 00074: val_acc did not improve from 0.83600
# Epoch 75/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3600 - acc: 0.8743 - val_loss: 0.5202 - val_acc: 0.8348
#
# Epoch 00075: val_acc did not improve from 0.83600
# Epoch 76/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3520 - acc: 0.8779 - val_loss: 0.5204 - val_acc: 0.8351
#
# Epoch 00076: val_acc did not improve from 0.83600
# Epoch 77/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3582 - acc: 0.8748 - val_loss: 0.5205 - val_acc: 0.8349
#
# Epoch 00077: val_acc did not improve from 0.83600
# Epoch 78/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3574 - acc: 0.8759 - val_loss: 0.5216 - val_acc: 0.8345
#
# Epoch 00078: val_acc did not improve from 0.83600
# Epoch 79/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3533 - acc: 0.8765 - val_loss: 0.5220 - val_acc: 0.8344
#
# Epoch 00079: val_acc did not improve from 0.83600
# Epoch 80/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 181ms/step - loss: 0.3553 - acc: 0.8763 - val_loss: 0.5218 - val_acc: 0.8351
#
# Epoch 00080: val_acc did not improve from 0.83600
# Epoch 81/100
# Learning rate:  1e-06
# 390/390 [==============================] - 71s 182ms/step - loss: 0.3578 - acc: 0.8759 - val_loss: 0.5217 - val_acc: 0.8349
#
# Epoch 00081: val_acc did not improve from 0.83600
# Epoch 82/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3566 - acc: 0.8754 - val_loss: 0.5196 - val_acc: 0.8351
#
# Epoch 00082: val_acc did not improve from 0.83600
# Epoch 83/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 182ms/step - loss: 0.3569 - acc: 0.8774 - val_loss: 0.5204 - val_acc: 0.8350
#
# Epoch 00083: val_acc did not improve from 0.83600
# Epoch 84/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3519 - acc: 0.8768 - val_loss: 0.5220 - val_acc: 0.8344
#
# Epoch 00084: val_acc did not improve from 0.83600
# Epoch 85/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 182ms/step - loss: 0.3555 - acc: 0.8767 - val_loss: 0.5218 - val_acc: 0.8343
#
# Epoch 00085: val_acc did not improve from 0.83600
# Epoch 86/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3567 - acc: 0.8761 - val_loss: 0.5204 - val_acc: 0.8354
#
# Epoch 00086: val_acc did not improve from 0.83600
# Epoch 87/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3581 - acc: 0.8747 - val_loss: 0.5226 - val_acc: 0.8346
#
# Epoch 00087: val_acc did not improve from 0.83600
# Epoch 88/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3571 - acc: 0.8740 - val_loss: 0.5194 - val_acc: 0.8355
#
# Epoch 00088: val_acc did not improve from 0.83600
# Epoch 89/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3531 - acc: 0.8773 - val_loss: 0.5208 - val_acc: 0.8353
#
# Epoch 00089: val_acc did not improve from 0.83600
# Epoch 90/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3552 - acc: 0.8763 - val_loss: 0.5218 - val_acc: 0.8350
#
# Epoch 00090: val_acc did not improve from 0.83600
# Epoch 91/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3579 - acc: 0.8759 - val_loss: 0.5210 - val_acc: 0.8349
#
# Epoch 00091: val_acc did not improve from 0.83600
# Epoch 92/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3561 - acc: 0.8760 - val_loss: 0.5196 - val_acc: 0.8354
#
# Epoch 00092: val_acc did not improve from 0.83600
# Epoch 93/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3530 - acc: 0.8772 - val_loss: 0.5205 - val_acc: 0.8355
#
# Epoch 00093: val_acc did not improve from 0.83600
# Epoch 94/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3552 - acc: 0.8782 - val_loss: 0.5211 - val_acc: 0.8352
#
# Epoch 00094: val_acc did not improve from 0.83600
# Epoch 95/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3494 - acc: 0.8778 - val_loss: 0.5205 - val_acc: 0.8355
#
# Epoch 00095: val_acc did not improve from 0.83600
# Epoch 96/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3561 - acc: 0.8741 - val_loss: 0.5201 - val_acc: 0.8351
#
# Epoch 00096: val_acc did not improve from 0.83600
# Epoch 97/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3589 - acc: 0.8758 - val_loss: 0.5188 - val_acc: 0.8353
#
# Epoch 00097: val_acc did not improve from 0.83600
# Epoch 98/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3532 - acc: 0.8780 - val_loss: 0.5209 - val_acc: 0.8349
#
# Epoch 00098: val_acc did not improve from 0.83600
# Epoch 99/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3541 - acc: 0.8765 - val_loss: 0.5205 - val_acc: 0.8349
#
# Epoch 00099: val_acc did not improve from 0.83600
# Epoch 100/100
# Learning rate:  5e-07
# 390/390 [==============================] - 71s 183ms/step - loss: 0.3609 - acc: 0.8735 - val_loss: 0.5190 - val_acc: 0.8355
#
# Epoch 00100: val_acc did not improve from 0.83600
# Model took 12627.43 seconds to train
# Accuracy on test data is: 83.58
